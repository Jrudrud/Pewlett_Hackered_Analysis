# %%
import pandas as pd

file_1 = pd.read_csv("../Data/dept_emp.csv")
file_2 = pd.read_csv("../Data/salaries.csv")
file_3 = pd.read_csv("../Data/employees.csv")
file_4 = pd.read_csv("../Data/departments.csv")

# %%
file_4.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %%
file_1.head()
# Out:
#    emp_no dept_no   from_date     to_date
# 0   10001    d005  1986-06-26  9999-01-01
# 1   10002    d007  1996-08-03  9999-01-01
# 2   10003    d004  1995-12-03  9999-01-01
# 3   10004    d004  1986-12-01  9999-01-01
# 4   10005    d003  1989-09-12  9999-01-01

# %%
file_2.head()
# Out:
#    emp_no  salary   from_date     to_date
# 0   10001   60117  1986-06-26  1987-06-26
# 1   10002   65828  1996-08-03  1997-08-03
# 2   10003   40006  1995-12-03  1996-12-02
# 3   10004   40054  1986-12-01  1987-12-01
# 4   10005   78228  1989-09-12  1990-09-12

# %%
file_3.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
emp_salaries_df = pd.merge(file_2, file_3, on=["emp_no"])
emp_salaries_df.head(30)
# Out:
#     emp_no  salary   from_date     to_date  birth_date first_name  \
# 0    10001   60117  1986-06-26  1987-06-26  1953-09-02     Georgi
# 1    10002   65828  1996-08-03  1997-08-03  1964-06-02    Bezalel
# 2    10003   40006  1995-12-03  1996-12-02  1959-12-03      Parto
# 3    10004   40054  1986-12-01  1987-12-01  1954-05-01  Chirstian
# 4    10005   78228  1989-09-12  1990-09-12  1955-01-21    Kyoichi
# 5    10006   40000  1990-08-05  1991-08-05  1953-04-20     Anneke
# 6    10007   56724  1989-02-10  1990-02-10  1957-05-23    Tzvetan
# 7    10008   46671  1998-03-11  1999-03-11  1958-02-19     Saniya
# 8    10009   60929  1985-02-18  1986-02-18  1952-04-19     Sumant
# 9    10010   72488  1996-11-24  1997-11-24  1963-06-01  Duangkaew
# 10   10011   42365  1990-01-22  1991-01-22  1953-11-07       Mary
# 11   10012   40000  1992-12-18  1993-12-18  1960-10-04   Patricio
# 12   10013   40000  1985-10-20  1986-10-20  1963-06-07  Eberhardt
# ...
